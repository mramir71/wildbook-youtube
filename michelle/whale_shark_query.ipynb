# %%
api_key = 'AIzaSyBe0j6fe0i0RAkwdcIEz7hWWRS1NeXEXs4' 

from apiclient.discovery import build

youtube = build('youtube', 'v3', developerKey = api_key)

req = youtube.search().list(q = 'whale shark', part = 'snippet', type = 'video', maxResults = 50) 
#NOTE: maxResults parameter has an upper limit of 50, which may yield problems as not ALL results are retrieved.
#req = youtube.videos().list(part = 'snippet', id = 'XlopHmUb0X4')
type(req)

result = req.execute()

# %%
result
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/05W0mHJk56wg1gsPhacnRcFjf5E"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/M5teaMhnXHgtvYJ_BaVY4ziBfY0"',
#    'id': {'kind': 'youtube#video', 'videoId': 'E9tpPWK7sag'},
#    'snippet': {'publishedAt': '2017-01-24T13:00:05.000Z',
#     'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#     'title': 'Investigating the Mysterious Whale Sharks of Mafia Island | National Geographic',
#     'description': "The whale sharks of Mafia Island are unusual because they don't migrate—and researchers want to know why. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E9tpPWK7sag/default.jpg',
#       'width': 120,
#       'height': 90},
# ...

# %%
result['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '"Bdx4f4ps3xCOOo1WZ91nTLkRZ_c/M5teaMhnXHgtvYJ_BaVY4ziBfY0"',
#  'id': {'kind': 'youtube#video', 'videoId': 'E9tpPWK7sag'},
#  'snippet': {'publishedAt': '2017-01-24T13:00:05.000Z',
#   'channelId': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#   'title': 'Investigating the Mysterious Whale Sharks of Mafia Island | National Geographic',
#   'description': "The whale sharks of Mafia Island are unusual because they don't migrate—and researchers want to know why. ➡ Subscribe: http://bit.ly/NatGeoSubscribe About ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E9tpPWK7sag/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/E9tpPWK7sag/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/E9tpPWK7sag/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'National Geographic',
#   'liveBroadcastContent': 'none'}}

# %%
for item in result['items']:
    print(item['snippet']['title'])
# Out:
# Investigating the Mysterious Whale Sharks of Mafia Island | National Geographic
# G I A N T S - Whale sharks of Isla Mujeres
# GoPro Awards: Ocean Ramsey and a Whale Shark
# Swimming in the Ocean with Whale Sharks and Manta Rays!
# 360 View of Feeding Whale Sharks at Georgia Aquarium!
# Whale Sharks: Meet The Gentle Giants Of The Sea! | The Blue Realm
# Whale Protects Diver From Shark | The Dodo
# GIANT WHALE SHARK EATS A GIANT WHALE - Feed and Grow Fish - Part 88 | Pungence
# TOP 10 BIGGEST SHARKS IN THE WORLD
# Whale shark sucks fish out of hole in fishing net - Conservation International (CI)
# Whale Shark Scares The Sh%t Out Of Me!!!
# Octonauts: Creature Report - Whale Shark
# Octonauts - s01e01 - The Whale Shark
# Swimming with Whale Sharks
# Two Whale Sharks Swim into Each Other at Georgia Aquarium
# 10 BIGGEST Underwater Creatures In The world!
# Whale Shark attacks diver
# A REALLY Friendly Baby Whale Shark
# Megalodon Vs Livyatan - Who Would Win?
# ...

# %%
video_urls = []
for item in result['items']:
    for each_id in item['id']: 
        if each_id == 'videoId':
            video_urls.append('www.youtube.com/watch?v='+ item['id']['videoId'])
print(video_urls)
len(video_urls)
# Out:
# ['www.youtube.com/watch?v=E9tpPWK7sag', 'www.youtube.com/watch?v=8U48NfAEEGQ', 'www.youtube.com/watch?v=8IJFJDrY2CY', 'www.youtube.com/watch?v=K4D89vyb4As', 'www.youtube.com/watch?v=EhE2bcHA1i4', 'www.youtube.com/watch?v=JyJJTf2rVd4', 'www.youtube.com/watch?v=NTw8MR67xv8', 'www.youtube.com/watch?v=VV-Ss0OIQOc', 'www.youtube.com/watch?v=x-RvZUHpPMc', 'www.youtube.com/watch?v=yqGYrlxWcdU', 'www.youtube.com/watch?v=QgG831EvoOk', 'www.youtube.com/watch?v=VOC0wB0_M6E', 'www.youtube.com/watch?v=-qrO2MYMoW0', 'www.youtube.com/watch?v=mn5a3XJhJd4', 'www.youtube.com/watch?v=hRFMX06mtpY', 'www.youtube.com/watch?v=K2SCAgFTU0M', 'www.youtube.com/watch?v=tEa0ceDtVAo', 'www.youtube.com/watch?v=1FUhPZkDkm8', 'www.youtube.com/watch?v=XzXZUqJPHIs', 'www.youtube.com/watch?v=jApMS38YR6w', 'www.youtube.com/watch?v=edY5aaMi1kQ', 'www.youtube.com/watch?v=MInBW8kG62A', 'www.youtube.com/watch?v=dV58x-MHR8A', 'www.youtube.com/watch?v=8QNgD6eKCJI', 'www.youtube.com/watch?v=jcaNSvpfDE4', 'www.youtube.com/watch
# ...
